# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf
import glob
from PIL import Image
from sklearn import metrics, cross_validation

# %%
# Set some parameters
IMG_WIDTH = 128
IMG_HEIGHT = 128
IMG_CHANNELS = 3
TRAIN_PATH = 'train'
TEST_PATH = 'test'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed
samples = [file for file in glob.glob('data/images/tmp/*.png')]
masks = [file for file in glob.glob('data/masks/tmp/*.npy')]

# %%
len(samples)
len(masks)
# Out:
# 1920

# %%
X = np.zeros((len(samples), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y = np.zeros((len(masks), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for i, id_ in tqdm(enumerate(samples), total=len(samples)):
    X[i] = imread(id_)[:,:,:IMG_CHANNELS]
    #img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    mask_ = np.load('data/masks/tmp/' + os.path.basename(id_)[:-4] + '.npy')
    mask = np.expand_dims(mask_, axis=-1)
    #imshow(np.squeeze(mask))
    #plt.show()
    Y[i] = mask
# Out:
# Getting and resizing train images and masks ...
#   0%|          | 0/1920 [00:00<?, ?it/s]
#
#   2%|▏         | 37/1920 [00:00<00:05, 363.87it/s]
#
#   4%|▍         | 73/1920 [00:00<00:05, 358.50it/s]
#
#   6%|▌         | 111/1920 [00:00<00:04, 362.83it/s]
#
#   8%|▊         | 149/1920 [00:00<00:04, 367.03it/s]
#
#  10%|▉         | 183/1920 [00:00<00:04, 360.66it/s]
#
#  12%|█▏        | 222/1920 [00:00<00:04, 365.17it/s]
#
#  14%|█▎        | 261/1920 [00:00<00:04, 367.36it/s]
#
#  16%|█▌        | 300/1920 [00:00<00:04, 369.28it/s]
#
#  18%|█▊        | 339/1920 [00:00<00:04, 370.82it/s]
#
#  20%|█▉        | 378/1920 [00:01<00:04, 372.07it/s]
#
#  22%|██▏       | 419/1920 [00:01<00:04, 374.95it/s]
#
#  24%|██▍       | 460/1920 [00:01<00:03, 377.19it/s]
#
#  26%|██▌       | 501/1920 [00:01<00:03, 379.35it/s]
#
#  28%|██▊       | 541/1920 [00:01<00:03, 378.61it/s]
#
#  30%|███       | 582/1920 [00:01<00:03, 380.33it/s]
#
#  32%|███▏      | 622/1920 [00:01<00:03, 379.22it/s]
#
#  34%|███▍      | 661/1920 [00:01<00:03, 379.35it/s]
#
#  37%|███▋      | 701/1920 [00:01<00:03, 380.26it/s]
#
#  39%|███▊      | 740/1920 [00:01<00:03, 380.45it/s]
#
#  41%|████      | 779/1920 [00:02<00:03, 380.28it/s]
#
#  43%|████▎     | 818/1920 [00:02<00:02, 380.41it/s]
#
#  45%|████▍     | 857/1920 [00:02<00:02, 380.34it/s]
#
#  47%|████▋     | 896/1920 [00:02<00:02, 380.07it/s]
#
#  49%|████▊     | 934/1920 [00:02<00:02, 379.93it/s]
#
#  51%|█████     | 972/1920 [00:02<00:02, 378.92it/s]
#
#  53%|█████▎    | 1010/1920 [00:02<00:02, 375.84it/s]
#
#  54%|█████▍    | 1046/1920 [00:02<00:02, 372.75it/s]
#
#  56%|█████▋    | 1080/1920 [00:02<00:02, 369.31it/s]
#
#  58%|█████▊    | 1113/1920 [00:03<00:02, 367.20it/s]
#
#  60%|█████▉    | 1150/1920 [00:03<00:02, 366.99it/s]
#
#  62%|██████▏   | 1184/1920 [00:03<00:02, 365.12it/s]
#
#  64%|██████▎   | 1221/1920 [00:03<00:01, 365.02it/s]
#
#  65%|██████▌   | 1255/1920 [00:03<00:01, 363.45it/s]
#
#  67%|██████▋   | 1292/1920 [00:03<00:01, 363.54it/s]
#
#  69%|██████▉   | 1332/1920 [00:03<00:01, 364.30it/s]
#
#  71%|███████▏  | 1372/1920 [00:03<00:01, 365.10it/s]
#
#  73%|███████▎  | 1411/1920 [00:03<00:01, 365.50it/s]
#
#  76%|███████▌  | 1454/1920 [00:03<00:01, 367.06it/s]
#
#  78%|███████▊  | 1493/1920 [00:04<00:01, 367.41it/s]
#
#  80%|███████▉  | 1532/1920 [00:04<00:01, 367.66it/s]
#
#  82%|████████▏ | 1571/1920 [00:04<00:00, 367.94it/s]
#
#  84%|████████▍ | 1610/1920 [00:04<00:00, 368.08it/s]
#
#  86%|████████▌ | 1651/1920 [00:04<00:00, 368.88it/s]
#
#  88%|████████▊ | 1690/1920 [00:04<00:00, 368.04it/s]
#
#  90%|█████████ | 1728/1920 [00:04<00:00, 366.82it/s]
#
#  92%|█████████▏| 1764/1920 [00:04<00:00, 365.78it/s]
#
#  94%|█████████▎| 1799/1920 [00:04<00:00, 364.70it/s]
#
#  95%|█████████▌| 1833/1920 [00:05<00:00, 363.95it/s]
#
#  98%|█████████▊| 1872/1920 [00:05<00:00, 364.31it/s]
#
#  99%|█████████▉| 1909/1920 [00:05<00:00, 364.39it/s]
#
# 100%|██████████| 1920/1920 [00:05<00:00, 363.53it/s]

# %%
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, Y, test_size=0.2, random_state=42)
print(len(X_train))
print(len(y_train))
# Out:
# 1536
# 1536

# %%
# Check if training data looks all right
ix = random.randint(0, len(X))
imshow(X[ix])
plt.show()
imshow(np.squeeze(Y[ix]))
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and

# %%
# Dice coefficient
def dice_coef(y_true, y_pred):
#    score, up_opt = tf.metrics.mean_iou(y_true, y_pred, 2)
    intersection = K.sum(y_pred * y_true)
    union = K.sum(y_pred + y_true - y_pred * y_true)
    score = 2 * intersection / (union + intersection)
    K.get_session().run(tf.local_variables_initializer())
    score = tf.identity(score)
    return score

def iou(y_true, y_pred):
    intersection = K.sum(y_pred * y_true)
    union = K.sum(y_pred + y_true) - intersection
    score = intersection / union
    K.get_session().run(tf.local_variables_initializer())
    score = tf.identity(score)
    return score

# %%
# Build U-Net model
inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
s = Lambda(lambda x: x / 255) (inputs)

c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (s)
c1 = Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = MaxPooling2D((2, 2)) (c1)

c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = MaxPooling2D((2, 2)) (c2)

c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = MaxPooling2D((2, 2)) (c3)

c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = MaxPooling2D(pool_size=(2, 2)) (c4)

c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
c5 = Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

u6 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = concatenate([u6, c4])
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u7 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = concatenate([u7, c3])
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = concatenate([u8, c2])
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = Conv2DTranspose(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = concatenate([u9, c1], axis=3)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)

model = Model(inputs=[inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=[dice_coef])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 128, 128, 3)  0
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 128, 128, 3)  0           input_10[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 128, 128, 8)  224         lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 128, 128, 8)  584         conv2d_172[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_37 (MaxPooling2D) (None, 64, 64, 8)    0           conv2d_173[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 64, 64, 16)   1168        max_pooling2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 64, 64, 16)   2320        conv2d_174[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_38 (MaxPooling2D) (None, 32, 32, 16)   0           conv2d_175[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 32, 32, 32)   4640        max_pooling2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 32, 32, 32)   9248        conv2d_176[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_39 (MaxPooling2D) (None, 16, 16, 32)   0           conv2d_177[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 16, 16, 64)   18496       max_pooling2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 16, 16, 64)   36928       conv2d_178[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_40 (MaxPooling2D) (None, 8, 8, 64)     0           conv2d_179[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 8, 8, 128)    73856       max_pooling2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 8, 8, 128)    147584      conv2d_180[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_37 (Conv2DTran (None, 16, 16, 64)   32832       conv2d_181[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 16, 16, 128)  0           conv2d_transpose_37[0][0]
#                                                                  conv2d_179[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 16, 16, 64)   73792       concatenate_37[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 16, 16, 64)   36928       conv2d_182[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_38 (Conv2DTran (None, 32, 32, 32)   8224        conv2d_183[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 32, 32, 64)   0           conv2d_transpose_38[0][0]
#                                                                  conv2d_177[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 32, 32, 32)   18464       concatenate_38[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 32, 32, 32)   9248        conv2d_184[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_39 (Conv2DTran (None, 64, 64, 16)   2064        conv2d_185[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 64, 64, 32)   0           conv2d_transpose_39[0][0]
#                                                                  conv2d_175[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 64, 64, 16)   4624        concatenate_39[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 64, 64, 16)   2320        conv2d_186[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_40 (Conv2DTran (None, 128, 128, 8)  520         conv2d_187[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 128, 128, 16) 0           conv2d_transpose_40[0][0]
#                                                                  conv2d_173[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 128, 128, 8)  1160        concatenate_40[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 128, 128, 8)  584         conv2d_188[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 128, 128, 1)  9           conv2d_189[0][0]
# ==================================================================================================
# Total params: 485,817
# Trainable params: 485,817
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit model
earlystopper = EarlyStopping(patience=5, verbose=1)
checkpointer = ModelCheckpoint('model-5.h5', verbose=1, save_best_only=True)
results = model.fit(X_train, y_train, validation_split=0.1, batch_size=4, epochs=30, 
                    callbacks=[earlystopper, checkpointer])
# Out:
# Train on 1382 samples, validate on 154 samples
# Epoch 1/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.4755 - dice_coef: 0.5069
# Epoch 00001: val_loss improved from inf to 0.36900, saving model to model-5.h5
# 1382/1382 [==============================] - 298s 215ms/step - loss: 0.4759 - dice_coef: 0.5070 - val_loss: 0.3690 - val_dice_coef: 0.6587
# Epoch 2/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.3387 - dice_coef: 0.6756
# Epoch 00002: val_loss improved from 0.36900 to 0.32083, saving model to model-5.h5
# 1382/1382 [==============================] - 68s 49ms/step - loss: 0.3387 - dice_coef: 0.6757 - val_loss: 0.3208 - val_dice_coef: 0.7231
# Epoch 3/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.3172 - dice_coef: 0.6967
# Epoch 00003: val_loss improved from 0.32083 to 0.30253, saving model to model-5.h5
# 1382/1382 [==============================] - 72s 52ms/step - loss: 0.3172 - dice_coef: 0.6968 - val_loss: 0.3025 - val_dice_coef: 0.7106
# Epoch 4/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2990 - dice_coef: 0.7167
# Epoch 00004: val_loss improved from 0.30253 to 0.29934, saving model to model-5.h5
# 1382/1382 [==============================] - 75s 54ms/step - loss: 0.2990 - dice_coef: 0.7168 - val_loss: 0.2993 - val_dice_coef: 0.7255
# Epoch 5/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2900 - dice_coef: 0.7252
# Epoch 00005: val_loss improved from 0.29934 to 0.28099, saving model to model-5.h5
# 1382/1382 [==============================] - 72s 52ms/step - loss: 0.2902 - dice_coef: 0.7251 - val_loss: 0.2810 - val_dice_coef: 0.7346
# Epoch 6/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2842 - dice_coef: 0.7310- ETA: 2s - loss: 0.2847 - dice_
# Epoch 00006: val_loss did not improve
# 1382/1382 [==============================] - 72s 52ms/step - loss: 0.2845 - dice_coef: 0.7309 - val_loss: 0.2995 - val_dice_coef: 0.7126
# Epoch 7/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2726 - dice_coef: 0.7445
# Epoch 00007: val_loss improved from 0.28099 to 0.27948, saving model to model-5.h5
# 1382/1382 [==============================] - 71s 51ms/step - loss: 0.2725 - dice_coef: 0.7444 - val_loss: 0.2795 - val_dice_coef: 0.7261
# Epoch 8/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2640 - dice_coef: 0.7526
# Epoch 00008: val_loss improved from 0.27948 to 0.27695, saving model to model-5.h5
# 1382/1382 [==============================] - 72s 52ms/step - loss: 0.2640 - dice_coef: 0.7526 - val_loss: 0.2770 - val_dice_coef: 0.7496
# Epoch 9/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2574 - dice_coef: 0.7588
# Epoch 00009: val_loss improved from 0.27695 to 0.27016, saving model to model-5.h5
# 1382/1382 [==============================] - 73s 52ms/step - loss: 0.2574 - dice_coef: 0.7588 - val_loss: 0.2702 - val_dice_coef: 0.7542
# Epoch 10/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2523 - dice_coef: 0.7633
# Epoch 00010: val_loss improved from 0.27016 to 0.26814, saving model to model-5.h5
# 1382/1382 [==============================] - 72s 52ms/step - loss: 0.2522 - dice_coef: 0.7634 - val_loss: 0.2681 - val_dice_coef: 0.7600
# Epoch 11/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2432 - dice_coef: 0.7726
# Epoch 00011: val_loss did not improve
# 1382/1382 [==============================] - 73s 53ms/step - loss: 0.2431 - dice_coef: 0.7726 - val_loss: 0.2776 - val_dice_coef: 0.7581
# Epoch 12/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2378 - dice_coef: 0.7781
# Epoch 00012: val_loss did not improve
# 1382/1382 [==============================] - 75s 54ms/step - loss: 0.2378 - dice_coef: 0.7781 - val_loss: 0.2779 - val_dice_coef: 0.7741
# Epoch 13/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2284 - dice_coef: 0.7874- ETA: 1s - loss: 0.2283 - dice_coef:
# Epoch 00013: val_loss improved from 0.26814 to 0.26637, saving model to model-5.h5
# 1382/1382 [==============================] - 75s 55ms/step - loss: 0.2285 - dice_coef: 0.7873 - val_loss: 0.2664 - val_dice_coef: 0.7684
# Epoch 14/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2217 - dice_coef: 0.7931
# Epoch 00014: val_loss did not improve
# 1382/1382 [==============================] - 73s 53ms/step - loss: 0.2217 - dice_coef: 0.7932 - val_loss: 0.2723 - val_dice_coef: 0.7812
# Epoch 15/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2134 - dice_coef: 0.8018
# Epoch 00015: val_loss did not improve
# 1382/1382 [==============================] - 82s 59ms/step - loss: 0.2135 - dice_coef: 0.8018 - val_loss: 0.2706 - val_dice_coef: 0.7715
# Epoch 16/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.2039 - dice_coef: 0.8107
# Epoch 00016: val_loss did not improve
# 1382/1382 [==============================] - 77s 56ms/step - loss: 0.2041 - dice_coef: 0.8106 - val_loss: 0.2813 - val_dice_coef: 0.7624
# Epoch 17/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.1978 - dice_coef: 0.8156
# Epoch 00017: val_loss did not improve
# 1382/1382 [==============================] - 75s 54ms/step - loss: 0.1979 - dice_coef: 0.8157 - val_loss: 0.2846 - val_dice_coef: 0.7914
# Epoch 18/30
# 1380/1382 [============================>.] - ETA: 0s - loss: 0.1968 - dice_coef: 0.8181- E
# Epoch 00018: val_loss did not improve
# 1382/1382 [==============================] - 71s 51ms/step - loss: 0.1967 - dice_coef: 0.8182 - val_loss: 0.2958 - val_dice_coef: 0.7809
# Epoch 00018: early stopping

# %%
# Predict on train, val and test
model = load_model('model-5.h5', custom_objects={'dice_coef': dice_coef})

# %%
preds_train = model.predict(X_train[:int(X_train.shape[0]*0.9)], verbose=1)
preds_val = model.predict(X_train[int(X_train.shape[0]*0.9):], verbose=1)
preds_test = model.predict(X_test, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)
# Out:
# 1382/1382 [==============================] - 58s 42ms/step
# 154/154 [==============================] - 3s 18ms/step
# 384/384 [==============================] - 7s 19ms/step

# %%
#print(preds_test_t)
#print(Y_test.shape)
#print(K.get_session().run(K.sum(preds_test_t * Y_test)))
#print(K.get_session().run(K.sum(preds_train_t)))
#print(K.get_session().run(Y_train[:int(Y_train.shape[0]*0.9)]))
print(K.get_session().run(dice_coef(preds_train_t, tf.to_int32(y_train[:int(y_train.shape[0]*0.9)]))))
print(K.get_session().run(dice_coef(preds_val_t, tf.to_int32(y_train[int(y_train.shape[0]*0.9):]))))
print(K.get_session().run(dice_coef(preds_test_t, tf.to_int32(y_test))))
# Out:
# 0.8606740042234744
# 0.8323469761251652
# 0.8345035533458168

# %%
# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(preds_test[i])

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
imshow(X_train[ix])
plt.show()
imshow(np.squeeze(y_train[ix]))
plt.show()
imshow(np.squeeze(preds_train_t[ix]))
plt.show()
# Out:
# /usr/local/lib/python3.6/site-packages/skimage/io/_plugins/matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
